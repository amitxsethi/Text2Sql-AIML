# %% [markdown]
# <a href="https://colab.research.google.com/github/amitxsethi/Text2Sql-AIML/blob/main/gensql_group6_amit_llama13B_full_spider_official_spider_evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi

import torch
print(f"\nCUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
# Out:
# Tue Nov 25 04:39:29 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-80GB          Off |   00000000:00:05.0 Off |                    0 |
# | N/A   37C    P0             55W /  400W |       0MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %% [markdown]
# The `nbstripout` tool can help clean up notebook metadata, which might resolve the rendering issue. You'll need to specify the exact filename of this notebook. After running the command, you might need to refresh your browser page for the changes to take effect.

# %%
# !git clone https://github.com/jieshi10/gensql.git
# %cd gensql
# !ls -la
print("✓ Repository cloned!")
# Out:
# Cloning into 'gensql'...
# remote: Enumerating objects: 149, done.
# remote: Counting objects: 100% (149/149), done.
# remote: Compressing objects: 100% (116/116), done.
# remote: Total 149 (delta 29), reused 148 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (149/149), 2.42 MiB | 3.46 MiB/s, done.
# Resolving deltas: 100% (29/29), done.
# /content/gensql
# total 132
# drwxr-xr-x 10 root root  4096 Nov 25 04:39 .
# drwxr-xr-x  1 root root  4096 Nov 25 04:39 ..
# drwxr-xr-x  4 root root  4096 Nov 25 04:39 benchmark
# drwxr-xr-x  3 root root  4096 Nov 25 04:39 bird_code
# drwxr-xr-x  2 root root  4096 Nov 25 04:39 docker
# drwxr-xr-x  8 root root  4096 Nov 25 04:39 .git
# -rw-r--r--  1 root root  3139 Nov 25 04:39 .gitignore
# -rw-r--r--  1 root root  1064 Nov 25 04:39 LICENSE
# -rw-r--r--  1 root root 37953 Nov 25 04:39 main.py
# drwxr-xr-x  2 root root  4096 Nov 25 04:39 pretrained
# -rw-r--r--  1 root root 16684 Nov 25 04:39 process_sql.py
# ...

# %%
# Fix dependency issues first
# !pip install -q jedi  # Fix ipython warning

# Install packages in the right order to avoid conflicts
print("Installing packages (this takes 2-3 minutes)...")

# Step 1: Core ML packages
# !pip install -q torch torchvision torchaudio

# Step 2: NLP packages with compatible versions
# !pip install -q 'transformers>=4.41.0,<5.0.0'
# !pip install -q sentence-transformers
# !pip install -q 'nltk>=3.9'  # Fix textblob conflict
# !pip install -q openai

# Step 3: SQL and utility packages
# !pip install -q 'sqlglot>=23.4'  # Use newer version
# !pip install -q sqlparse
# !pip install -q func-timeout
# !pip install -q scikit-learn

# Step 4: Install vLLM last (takes longest)
print("\nInstalling vLLM (this takes 1-2 minutes)...")
# !pip install -q vllm

print("\n✓ All packages installed successfully!")
print("\nInstalled versions:")
# !pip list | grep -E 'torch|transformers|vllm|nltk|sqlglot'
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 73.4 MB/s eta 0:00:00
# Installing packages (this takes 2-3 minutes)...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 3.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#
# Installing vLLM (this takes 1-2 minutes)...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 9.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 370.3/370.3 MB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 355.0/355.0 kB 33.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.0/183.0 kB 19.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 105.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 kB 11.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 4.4 MB/s eta 0:00:00
# ...

# %%
import nltk
import ssl

ssl._create_default_https_context = ssl._create_unverified_context
nltk.download('punkt', quiet=True)
nltk.download('averaged_perceptron_tagger', quiet=True)

print("✓ NLTK data downloaded!")
# Out:
# ✓ NLTK data downloaded!

# %%
print("Fixing sentence_transformers compatibility...")

# Fix SentenceTransformer.py
with open('sentence_transformers/SentenceTransformer.py', 'r') as f:
    content = f.read()
content = content.replace(
    'from huggingface_hub import HfApi, HfFolder, Repository, hf_hub_url, cached_download',
    'from huggingface_hub import HfApi, HfFolder, Repository, hf_hub_url, hf_hub_download'
)
with open('sentence_transformers/SentenceTransformer.py', 'w') as f:
    f.write(content)

# Fix util.py
with open('sentence_transformers/util.py', 'r') as f:
    content = f.read()

content = content.replace(
    'from huggingface_hub import HfApi, hf_hub_url, cached_download, HfFolder',
    '''from huggingface_hub import HfApi, hf_hub_url, hf_hub_download, HfFolder
try:
    from huggingface_hub import cached_download
except ImportError:
    cached_download = None'''
)

with open('sentence_transformers/util.py', 'w') as f:
    f.write(content)

print("✓ Fixed sentence_transformers!")
# Out:
# Fixing sentence_transformers compatibility...
# ✓ Fixed sentence_transformers!

# %%
from huggingface_hub import snapshot_download

print("Downloading BGE model (~1.3 GB)...")
print("This will take 2-3 minutes...\n")

model_path = snapshot_download(
    repo_id='BAAI/bge-large-en-v1.5',
    local_dir='./pretrained/bge-large-en-v1.5',
    local_dir_use_symlinks=False
)

print(f"\n✓ BGE model downloaded!")
# !du -sh pretrained/bge-large-en-v1.5
# Out:
# ...
# This will take 2-3 minutes...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:979: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# ...

# %%
import os

os.makedirs('benchmark', exist_ok=True)

print("Downloading Spider dataset (~100 MB)...")
# !wget -q --show-progress -O benchmark/spider.zip "https://drive.usercontent.google.com/download?id=1TqleXec_OykOYFREKKtschzY29dUcVAQ&export=download&confirm=t"

print("\nExtracting...")
# !cd benchmark && unzip -q spider.zip && rm spider.zip

print("✓ Spider dataset ready!")
# !du -sh benchmark/spider
# !ls benchmark/spider/
# Out:
# ...
# benchmark/spider.zi 100%[===================>]  95.12M  68.1MB/s    in 1.4s
#
# Extracting...
# ✓ Spider dataset ready!
# 878M	benchmark/spider
# database      dev.json	  tables.json	  train_others.json
# dev_gold.sql  README.txt  train_gold.sql  train_spider.json

# %%
import subprocess
import time

print("="*70)
print("DOWNLOADING CODELLAMA-13B-INSTRUCT")
print("="*70)
print("\n📦 Size: ~26GB")
print("⏱️  Time: 15-20 minutes on Colab Pro A100")
print("\nStarting download...\n")

start_time = time.time()

# Install git-lfs
subprocess.run(['git', 'lfs', 'install'], check=True)
print("✓ Git LFS installed\n")

# Clone the model
subprocess.run([
    'git', 'clone',
    'https://huggingface.co/codellama/CodeLlama-13b-Instruct-hf',
    'models/codellama-13b'
], check=True)

elapsed = (time.time() - start_time) / 60
print(f"\n{'='*70}")
print(f"✅ DOWNLOAD COMPLETE in {elapsed:.1f} minutes!")
print('='*70)

# Verify
# !echo "\nModel size:"
# !du -sh models/codellama-13b

# !echo "\nModel files:"
# !ls -lh models/codellama-13b/*.json
# Out:
# ...
# DOWNLOADING CODELLAMA-13B-INSTRUCT
# ...
#
# 📦 Size: ~26GB
# ⏱️  Time: 15-20 minutes on Colab Pro A100
#
# Starting download...
#
# ✓ Git LFS installed
#
#
# ...
# ✅ DOWNLOAD COMPLETE in 8.4 minutes!
# ...
# \nModel size:
# 98G	models/codellama-13b
# \nModel files:
# -rw-r--r-- 1 root root  589 Nov 25 05:43 models/codellama-13b/config.json
# -rw-r--r-- 1 root root  116 Nov 25 05:43 models/codellama-13b/generation_config.json
# -rw-r--r-- 1 root root  31K Nov 25 05:43 models/codellama-13b/model.safetensors.index.json
# -rw-r--r-- 1 root root  30K Nov 25 05:43 models/codellama-13b/pytorch_model.bin.index.json
# -rw-r--r-- 1 root root  411 Nov 25 05:43 models/codellama-13b/special_tokens_map.json
# -rw-r--r-- 1 root root 1.6K Nov 25 05:43 models/codellama-13b/tokenizer_config.json
# -rw-r--r-- 1 root root 1.8M Nov 25 05:43 models/codellama-13b/tokenizer.json

# %%
import subprocess
import time
import requests

# Kill any old processes
print("Stopping old vLLM processes...")
subprocess.run("pkill -9 -f vllm", shell=True)
time.sleep(3)
print("✓ Stopped\n")
# Out:
# Stopping old vLLM processes...
# ✓ Stopped

# %%
# !lsof -ti :8000 && echo "⚠️  Port in use" || echo "✓ Port free"
# Out:
# ✓ Port free

# %%
# Update the LLM client to use port 8000
with open('main.py', 'r') as f:
    code = f.read()

# Change port from 8080 to 8000
code = code.replace("port=8080", "port=8000")
code = code.replace("LLMClient(host='127.0.0.1', port=8080)",
                   "LLMClient(host='127.0.0.1', port=8000)")
code = code.replace("DB_NAME: str='bird'", "DB_NAME: str='spider'")

with open('main.py', 'w') as f:
    f.write(code)

print("✓ Updated main.py to use port 8000")
# Out:
# ✓ Updated main.py to use port 8000

# %%
print("="*70)
print("OPTIMIZING SETTINGS FOR CODELLAMA-13B")
print("="*70)

# IMPORTANT: Use MAX_ITER=3 (not 5!)
# IMPORTANT: Use FEW_SHOT_K=4 (not 8!)

import subprocess

# Update MAX_ITER to 3
subprocess.run(['sed', '-i', 's/MAX_ITER = 5/MAX_ITER = 3/', 'main.py'])
subprocess.run(['sed', '-i', 's/MAX_ITER = [0-9]\\+/MAX_ITER = 3/', 'main.py'])

# Update FEW_SHOT_K to 4
subprocess.run(['sed', '-i', 's/FEW_SHOT_K = 8/FEW_SHOT_K = 4/', 'main.py'])
subprocess.run(['sed', '-i', 's/FEW_SHOT_K = [0-9]\\+/FEW_SHOT_K = 4/', 'main.py'])

# Update max_workers to 12 (optimal for 13B on A100)
subprocess.run(['sed', '-i', 's/max_workers=[0-9]\\+/max_workers=12/', 'main.py'])

# Make sure we're running full dataset
subprocess.run(['sed', '-i', 's/^\\s*data = data\\[:/# data = data[:/', 'main.py'])

print("\n✓ Settings updated!\n")
print("Current configuration:")
# !grep "MAX_ITER = " main.py | grep -v "^#" | head -1
# !grep "FEW_SHOT_K = " main.py | grep -v "^#" | head -1
# !grep "max_workers=" main.py | grep -v "^#" | head -1

print("\n" + "="*70)
print("OPTIMIZED FOR CODELLAMA-13B:")
print("="*70)
print("  MAX_ITER = 3      (vs 5 in 7B run → 40% faster)")
print("  FEW_SHOT_K = 4    (vs 8 in 7B run → less context overflow)")
print("  max_workers = 12  (optimized for A100)")
print("  Full dataset      (1,034 examples)")
print("="*70)
print("\nExpected improvements over 7B:")
print("  • EX: 50% → 70-75% (+20-25%)")
print("  • Null rate: 25% → 10-15% (half the failures)")
print("  • Complex queries: Much better (JOINs, subqueries, NOT EXISTS)")
print("="*70)
# Out:
# ...
# OPTIMIZING SETTINGS FOR CODELLAMA-13B
# ...
#
# ✓ Settings updated!
#
# Current configuration:
# MAX_ITER = 3
# FEW_SHOT_K = 4
#     with ThreadPoolExecutor(max_workers=12) as executor:
#
# ...
# OPTIMIZED FOR CODELLAMA-13B:
# ...
#   MAX_ITER = 3      (vs 5 in 7B run → 40% faster)
#   FEW_SHOT_K = 4    (vs 8 in 7B run → less context overflow)
#   max_workers = 12  (optimized for A100)
#   Full dataset      (1,034 examples)
# ...
#
# Expected improvements over 7B:
#   • EX: 50% → 70-75% (+20-25%)
#   • Null rate: 25% → 10-15% (half the failures)
#   • Complex queries: Much better (JOINs, subqueries, NOT EXISTS)
# ...

# %%
import subprocess
import time
import requests

print("="*70)
print("STARTING VLLM WITH CODELLAMA-13B")
print("="*70)

# 1. Clean up old processes
print("\n1. Cleaning up old vLLM processes...")
subprocess.run("pkill -9 -f vllm", shell=True)
time.sleep(3)
print("   ✓ Cleaned")

# 2. Check GPU
print("\n2. GPU Status:")
# !nvidia-smi --query-gpu=name,memory.total,memory.free,memory.used --format=csv

# 3. Start vLLM
print("\n3. Starting vLLM server...")
print("   Model: CodeLlama-13B-Instruct")
print("   GPU memory: 0.85 (34/40GB)")
print("   Max length: 1536 tokens")
print("   Max sequences: 12")
print("\n   ⏳ Loading model (60-90 seconds)...\n")

subprocess.Popen([
    'python', '-m', 'vllm.entrypoints.openai.api_server',
    '--host', '127.0.0.1',
    '--port', '8000',
    '--model', './models/codellama-13b',
    '--served-model-name', 'CodeLlama-13B-Instruct',
    '--max-model-len', '1536',
    '--gpu-memory-utilization', '0.85',
    '--dtype', 'float16',
    '--max-num-seqs', '12',
    '--disable-log-requests'
], stdout=open('vllm_codellama13b.log', 'w'), stderr=subprocess.STDOUT)

# 4. Wait for server
print("4. Waiting for server...")
server_ready = False
for i in range(20):
    time.sleep(10)
    try:
        r = requests.get('http://127.0.0.1:8000/health', timeout=2)
        if r.status_code == 200:
            models = requests.get('http://127.0.0.1:8000/v1/models').json()
            print(f"\n{'='*70}")
            print(f"✅ SERVER READY after {(i+1)*10} seconds!")
            print(f"✅ Model: {models['data'][0]['id']}")
            print('='*70)
            print("\n🚀 Ready to run Gen-SQL!\n")
            server_ready = True
            break
    except Exception as e:
        print(f"   ⏳ {(i+1)*10}s...")

if not server_ready:
    print("\n❌ Server failed to start. Checking logs:")
    # !tail -50 vllm_codellama13b.log
# Out:
# ...
# STARTING VLLM WITH CODELLAMA-13B
# ...
#
# 1. Cleaning up old vLLM processes...
#    ✓ Cleaned
#
# 2. GPU Status:
# name, memory.total [MiB], memory.free [MiB], memory.used [MiB]
# NVIDIA A100-SXM4-80GB, 81920 MiB, 81216 MiB, 5 MiB
#
# 3. Starting vLLM server...
#    Model: CodeLlama-13B-Instruct
#    GPU memory: 0.85 (34/40GB)
#    Max length: 1536 tokens
#    Max sequences: 12
#
#    ⏳ Loading model (60-90 seconds)...
#
# 4. Waiting for server...
#    ⏳ 10s...
#    ⏳ 20s...
#    ⏳ 30s...
#    ⏳ 40s...
#    ⏳ 50s...
#    ⏳ 60s...
#    ⏳ 70s...
#    ⏳ 80s...
#    ⏳ 90s...
#    ⏳ 100s...
#    ⏳ 110s...
#
# ...
# ✅ SERVER READY after 120 seconds!
# ✅ Model: CodeLlama-13B-Instruct
# ...
#
# 🚀 Ready to run Gen-SQL!

# %%
# !tail -100 vllm_codellama.log
# Out:
# Loading safetensors checkpoint shards:   0% Completed | 0/2 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards:  50% Completed | 1/2 [00:01<00:01,  1.60s/it]
# Loading safetensors checkpoint shards: 100% Completed | 2/2 [00:06<00:00,  3.42s/it]
# Loading safetensors checkpoint shards: 100% Completed | 2/2 [00:06<00:00,  3.15s/it]
# (EngineCore_DP0 pid=2550)
# (EngineCore_DP0 pid=2550) INFO 11-25 04:46:43 [default_loader.py:314] Loading weights took 6.53 seconds
# (EngineCore_DP0 pid=2550) INFO 11-25 04:46:44 [gpu_model_runner.py:3338] Model loading took 12.5563 GiB memory and 34.102175 seconds
# (EngineCore_DP0 pid=2550) INFO 11-25 04:46:52 [backends.py:631] Using cache directory: /root/.cache/vllm/torch_compile_cache/319dc32337/rank_0_0/backbone for vLLM's torch.compile
# (EngineCore_DP0 pid=2550) INFO 11-25 04:46:52 [backends.py:647] Dynamo bytecode transform time: 7.76 s
# ...

# %%
# !grep -n "spider"  main.py | head -20
# Out:
# 79:DB_NAME: str='spider'
# 80:# DB_NAME: str='spider'
# 94:elif DB_NAME == 'spider':
# 95:    # spider
# 96:    DB_SET_PATH: str='benchmark/spider/database/*'
# 97:    # DB_SET_PATH: str='spider_code/spider_ext/*'
# 98:    TRAINING_SET_PATHS: List[str]=['benchmark/spider/train_others.json', 'benchmark/spider/train_spider.json']
# 100:    DEV_SET_PATH: str='benchmark/spider/dev.json'

# %%
import nltk
import ssl

# Fix SSL
ssl._create_default_https_context = ssl._create_unverified_context

# Download the new punkt_tab (required for NLTK 3.9+)
print("Downloading punkt_tab...")
nltk.download('punkt_tab', quiet=False)
nltk.download('averaged_perceptron_tagger_eng', quiet=False)

# Also download the old ones as backup
nltk.download('punkt', quiet=False)
nltk.download('averaged_perceptron_tagger', quiet=False)

print("\n✓ All NLTK data downloaded!")
# Out:
# ...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# ✓ All NLTK data downloaded!
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# Create output directory
print("\n2. Creating output directory...")
import os
os.makedirs('output', exist_ok=True)
print("   ✓ Created")
# Out:
# 2. Creating output directory...
#    ✓ Created

# %%
# !python main.py
# Out:
# Use Model: CodeLlama-13B-Instruct
# 2025-11-25 06:04:55.727303: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-25 06:04:55.745405: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764050695.767259   54031 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764050695.773938   54031 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
import glob
import json

# Find the output file
output_files = glob.glob('output/*.json')
print(f"Output file: {output_files[0]}\n")

# Quick stats
with open(output_files[0], 'r') as f:
    results = json.load(f)

results = [r for r in results if r is not None]
print(f"Total examples processed: {len(results)}")
print(f"Avg time per example: {sum(r['time'] for r in results)/len(results):.2f}s")
print(f"Total time: {sum(r['time'] for r in results):.2f}s\n")

# Show first few questions
print("Questions processed:")
for i, r in enumerate(results[:5]):
    print(f"  {i+1}. {r['question'][:60]}...")
# Out:
# Output file: output/CodeLlama-13B-Instruct-spider-gtrr_column-S30C200-SS4CS6-L3-q_skltn-sql_skltn-sql_post_process-fs4-dev.json
#
# Total examples processed: 799
# Avg time per example: 4.98s
# Total time: 3975.31s
#
# Questions processed:
#   1. How many singers do we have?...
#   2. What is the total number of singers?...
#   3. Show name, country, age for all singers ordered by age from ...
#   4. What are the names, countries, and ages for every singer in ...
#   5. What is the average, minimum, and maximum age of all singers...

# %%
# ====================================================================
# CREATE WORKING CONVERSION SCRIPT (Original version that worked)
# ====================================================================

conversion_script = '''import json
from copy import deepcopy
import sys
import glob

# Auto-detect latest output file
output_files = glob.glob('output/*-spider-*.json')
output_files = [f for f in output_files if '_report' not in f and '_errors' not in f and '_gold' not in f and '_pred' not in f and '_failed' not in f]

if not output_files:
    print("❌ No output files found!")
    sys.exit(1)

# Get the most recent file
import os
output_files.sort(key=lambda x: os.path.getmtime(x), reverse=True)
FILENAME = output_files[0].replace('.json', '')
INPUT_FILE = FILENAME + '.json'

print(f"📂 Processing: {INPUT_FILE}")

OUTPUT_GOLD = FILENAME + '-gold.txt'
OUTPUT_PRED = FILENAME + '-pred.txt'

field = 'infer'

with open(INPUT_FILE, encoding='utf-8') as f:
    data = json.load(f)


def get_dict_value(r: dict, field: str):
    if '.' in field:
        field = field.split('.')
        for k in field:
            try:
                k = int(k)
            except:
                pass
            r = r[k]
        return r
    else:
        return r[field]


def set_dict_value(r: dict, field: str, value):
    if '.' in field:
        field = field.split('.')
        for k in field[:-1]:
            try:
                k = int(k)
            except:
                pass
            if k not in r:
                r[k] = {}
            r = r[k]
        k = field[-1]
        try:
            k = int(k)
        except:
            pass
        r[k] = value
    else:
        r[field] = value


with open('benchmark/spider/dev.json', encoding='utf-8') as f:
    dev_data = json.load(f)

print(f"Total examples: {len(data)}")
print(f"Valid results: {len([r for r in data if r and isinstance(r, dict)])}")
print(f"Null results: {len([r for r in data if not r])}")

with open(OUTPUT_GOLD, 'w', encoding='utf-8') as fg, \\
        open(OUTPUT_PRED, 'w', encoding='utf-8') as fp:
    for r, dev_r in zip(data, dev_data):
        if r is None:
            r = deepcopy(dev_r)
            r['output'] = r['query']
            set_dict_value(r, field, 'SELECT')

        # Handle case where r might not be a dict
        if not isinstance(r, dict):
            r = deepcopy(dev_r)
            r['output'] = r['query']
            set_dict_value(r, field, 'SELECT')

        assert r['question'] == dev_r['question']
        assert r['output'] == dev_r['query']
        assert r['db'] == dev_r['db_id']

        gold = r['output']
        pred = get_dict_value(r, field).replace('\\n', ' ').replace('\\t', ' ').strip()
        db = r['db']

        fg.write(gold + '\\t' + db + '\\n')
        fp.write(pred + '\\t' + db + '\\n')

print(f"\\n✓ Conversion complete!")
print(f"   Gold: {OUTPUT_GOLD}")
print(f"   Pred: {OUTPUT_PRED}")
'''

# Write it
with open('spider_code/convert_output_ext.py', 'w') as f:
    f.write(conversion_script)

print("✅ Conversion script created!")
print("\nNow run it:")
print("  !python spider_code/convert_output_ext.py")
# Out:
# ✅ Conversion script created!
#
# Now run it:
#   !python spider_code/convert_output_ext.py

# %%
# !rm -f output/*-gold.txt output/*-pred.txt

# Run conversion
# !python spider_code/convert_output_ext.py

# Verify
# !echo "\nLine counts (should be 1034 each):"
# !wc -l output/*-gold.txt output/*-pred.txt
# Out:
# 📂 Processing: output/CodeLlama-13B-Instruct-spider-gtrr_column-S30C200-SS4CS6-L3-q_skltn-sql_skltn-sql_post_process-fs4-dev-failed-failed.json
# Total examples: 0
# Valid results: 0
# Null results: 0
#
# ✓ Conversion complete!
#    Gold: output/CodeLlama-13B-Instruct-spider-gtrr_column-S30C200-SS4CS6-L3-q_skltn-sql_skltn-sql_post_process-fs4-dev-failed-failed-gold.txt
#    Pred: output/CodeLlama-13B-Instruct-spider-gtrr_column-S30C200-SS4CS6-L3-q_skltn-sql_skltn-sql_post_process-fs4-dev-failed-failed-pred.txt
# \nLine counts (should be 1034 each):
# 0 output/CodeLlama-13B-Instruct-spider-gtrr_column-S30C200-SS4CS6-L3-q_skltn-sql_skltn-sql_post_process-fs4-dev-failed-failed-gold.txt
# 0 output/CodeLlama-13B-Instruct-spider-gtrr_column-S30C200-SS4CS6-L3-q_skltn-sql_skltn-sql_post_process-fs4-dev-failed-failed-pred.txt
# 0 total

# %%
# ====================================================================
# RUN CONVERSION WITH CORRECT FILE
# ====================================================================

import json
from copy import deepcopy

# Explicitly use the correct file
INPUT_FILE = 'output/CodeLlama-13B-Instruct-spider-gtrr_column-S30C200-SS4CS6-L3-q_skltn-sql_skltn-sql_post_process-fs4-dev.json'
OUTPUT_GOLD = 'output/CodeLlama-13B-Instruct-spider-gtrr_column-S30C200-SS4CS6-L3-q_skltn-sql_skltn-sql_post_process-fs4-dev-gold.txt'
OUTPUT_PRED = 'output/CodeLlama-13B-Instruct-spider-gtrr_column-S30C200-SS4CS6-L3-q_skltn-sql_skltn-sql_post_process-fs4-dev-pred.txt'

print("="*70)
print("CONVERTING RESULTS TO EVALUATION FORMAT")
print("="*70)
print(f"\n📂 Input:  {INPUT_FILE}")
print(f"📝 Output: {OUTPUT_GOLD}")
print(f"📝 Output: {OUTPUT_PRED}\n")

# Load Gen-SQL results
with open(INPUT_FILE, encoding='utf-8') as f:
    data = json.load(f)

# Load ground truth
with open('benchmark/spider/dev.json', encoding='utf-8') as f:
    dev_data = json.load(f)

print(f"Results: {len(data)} examples")
print(f"Ground truth: {len(dev_data)} examples")

valid = len([r for r in data if r and isinstance(r, dict)])
null = len(data) - valid
print(f"Valid: {valid} | Null: {null}\n")

# Convert
with open(OUTPUT_GOLD, 'w', encoding='utf-8') as fg, \
        open(OUTPUT_PRED, 'w', encoding='utf-8') as fp:

    for r, dev_r in zip(data, dev_data):
        # Handle null results
        if r is None or not isinstance(r, dict):
            r = {
                'question': dev_r['question'],
                'output': dev_r['query'],
                'db': dev_r['db_id'],
                'infer': 'SELECT'  # Placeholder for failed
            }

        gold = dev_r['query']
        pred = r.get('infer', 'SELECT').replace('\n', ' ').replace('\t', ' ').strip()
        db = dev_r['db_id']

        fg.write(gold + '\t' + db + '\n')
        fp.write(pred + '\t' + db + '\n')

print("✅ Conversion complete!\n")

# Verify
# !wc -l {OUTPUT_GOLD} {OUTPUT_PRED}
print("\n✓ Both files should have 1034 lines")
# Out:
# ...
# CONVERTING RESULTS TO EVALUATION FORMAT
# ...
#
# 📂 Input:  output/CodeLlama-13B-Instruct-spider-gtrr_column-S30C200-SS4CS6-L3-q_skltn-sql_skltn-sql_post_process-fs4-dev.json
# 📝 Output: output/CodeLlama-13B-Instruct-spider-gtrr_column-S30C200-SS4CS6-L3-q_skltn-sql_skltn-sql_post_process-fs4-dev-gold.txt
# 📝 Output: output/CodeLlama-13B-Instruct-spider-gtrr_column-S30C200-SS4CS6-L3-q_skltn-sql_skltn-sql_post_process-fs4-dev-pred.txt
#
# Results: 1034 examples
# Ground truth: 1034 examples
# Valid: 799 | Null: 235
#
# ✅ Conversion complete!
#
#   1034 output/CodeLlama-13B-Instruct-spider-gtrr_column-S30C200-SS4CS6-L3-q_skltn-sql_skltn-sql_post_process-fs4-dev-gold.txt
#   1034 output/CodeLlama-13B-Instruct-spider-gtrr_column-S30C200-SS4CS6-L3-q_skltn-sql_skltn-sql_post_process-fs4-dev-pred.txt
#   2068 total
#
# ✓ Both files should have 1034 lines

# %%
# !python3 benchmark/test-suite-sql-eval/evaluation_2.py \
    --gold output/CodeLlama-13B-Instruct-spider-gtrr_column-S30C200-SS4CS6-L3-q_skltn-sql_skltn-sql_post_process-fs4-dev-gold.txt \
    --pred output/CodeLlama-13B-Instruct-spider-gtrr_column-S30C200-SS4CS6-L3-q_skltn-sql_skltn-sql_post_process-fs4-dev-pred.txt \
    --etype all \
    --db benchmark/spider/database \
    --out_file output/CodeLlama-13B-Instruct-spider-gtrr_column-S30C200-SS4CS6-L3-q_skltn-sql_skltn-sql_post_process-fs4-dev-failed.json \
    --table benchmark/spider/tables.json \
    --progress_bar_for_each_datapoint
# Out:
# benchmark/spider/database/concert_singer/concert_singer.sqlite
# SELECT  count(*) FROM singer
# 100% 1/1 [00:00<00:00, 237.56it/s]
# benchmark/spider/database/concert_singer/concert_singer.sqlite
# SELECT  count(*) FROM singer
# 100% 1/1 [00:00<00:00, 344.93it/s]
# benchmark/spider/database/concert_singer/concert_singer.sqlite
# SELECT  Name ,  Country ,  Age FROM singer ORDER BY Age DESC
# 100% 1/1 [00:00<00:00, 340.25it/s]
# benchmark/spider/database/concert_singer/concert_singer.sqlite
# SELECT  name ,  country ,  age FROM singer ORDER BY age DESC
# 100% 1/1 [00:00<00:00, 345.18it/s]
# benchmark/spider/database/concert_singer/concert_singer.sqlite
# SELECT  avg(age) ,  min(age) ,  max(age) FROM singer WHERE country  =  'France'
# 100% 1/1 [00:00<00:00, 360.55it/s]
# benchmark/spider/database/concert_singer/concert_singer.sqlite
# SELECT  avg(age) ,  min(age) ,  max(age) FROM singer WHERE country  =  'France'
# 100% 1/1 [00:00<00:00, 357.78it/s]
# ...

# %%
import json
import re

print("="*70)

# Load results to count valid/null
with open('output/CodeLlama-13B-Instruct-spider-gtrr_column-S30C200-SS4CS6-L3-q_skltn-sql_skltn-sql_post_process-fs4-dev.json') as f:
    results = json.load(f)

valid_count = len([r for r in results if r and isinstance(r, dict)])
null_count = len(results) - valid_count

# Load gold and pred to calculate normalized EM
with open('output/CodeLlama-13B-Instruct-spider-gtrr_column-S30C200-SS4CS6-L3-q_skltn-sql_skltn-sql_post_process-fs4-dev-gold.txt') as f:
    gold_lines = f.readlines()

with open('output/CodeLlama-13B-Instruct-spider-gtrr_column-S30C200-SS4CS6-L3-q_skltn-sql_skltn-sql_post_process-fs4-dev-pred.txt') as f:
    pred_lines = f.readlines()

# Normalize SQL
def normalize(sql):
    sql = sql.lower().strip()
    sql = re.sub(r'\s+', ' ', sql)
    sql = re.sub(r'\s*,\s*', ', ', sql)
    sql = re.sub(r'\s*\(\s*', '(', sql)
    sql = re.sub(r'\s*\)\s*', ')', sql)
    return sql.strip()

normalized_matches = 0
for g, p in zip(gold_lines, pred_lines):
    gold_sql = g.split('\t')[0].strip()
    pred_sql = p.split('\t')[0].strip()

    if normalize(gold_sql) == normalize(pred_sql):
        normalized_matches += 1

normalized_em = (normalized_matches / 1034) * 100

# Run official evaluation to get EX
print("Running official evaluation for Execution Accuracy...\n")
# !python3 benchmark/test-suite-sql-eval/evaluation_2.py \
    --gold output/CodeLlama-13B-Instruct-spider-gtrr_column-S30C200-SS4CS6-L3-q_skltn-sql_skltn-sql_post_process-fs4-dev-gold.txt \
    --pred output/CodeLlama-13B-Instruct-spider-gtrr_column-S30C200-SS4CS6-L3-q_skltn-sql_skltn-sql_post_process-fs4-dev-pred.txt \
    --etype all \
    --db benchmark/spider/database \
    --out_file output/CodeLlama-13B-Instruct-spider-gtrr_column-S30C200-SS4CS6-L3-q_skltn-sql_skltn-sql_post_process-fs4-dev-failed.json \
    --table benchmark/spider/tables.json \
    --progress_bar_for_each_datapoint

# Load failed.json to get correct count
with open('output/CodeLlama-13B-Instruct-spider-gtrr_column-S30C200-SS4CS6-L3-q_skltn-sql_skltn-sql_post_process-fs4-dev-failed.json') as f:
    failed_data = json.load(f)

correct_count = 1034 - len(failed_data)

print("\n" + "="*70)
print("FINAL RESULTS SUMMARY")
print("="*70)
print(f"Normalized EM:                    {normalized_em:.1f}% (case-insensitive)")
print(f"✅ Execution Accuracy (EX):        {correct_count/1034*100:.1f}% ⭐ MAIN METRIC")
print(f"\nGeneration success rate:          {valid_count/1034*100:.1f}%")
print(f"Null/failed generations:          {null_count/1034*100:.1f}%")
print("="*70)
# Out:
# ...
# Running official evaluation for Execution Accuracy...
#
# benchmark/spider/database/concert_singer/concert_singer.sqlite
# SELECT  count(*) FROM singer
# 100% 1/1 [00:00<00:00, 229.25it/s]
# benchmark/spider/database/concert_singer/concert_singer.sqlite
# SELECT  count(*) FROM singer
# 100% 1/1 [00:00<00:00, 343.29it/s]
# benchmark/spider/database/concert_singer/concert_singer.sqlite
# SELECT  Name ,  Country ,  Age FROM singer ORDER BY Age DESC
# 100% 1/1 [00:00<00:00, 352.05it/s]
# benchmark/spider/database/concert_singer/concert_singer.sqlite
# SELECT  name ,  country ,  age FROM singer ORDER BY age DESC
# 100% 1/1 [00:00<00:00, 340.89it/s]
# benchmark/spider/database/concert_singer/concert_singer.sqlite
# SELECT  avg(age) ,  min(age) ,  max(age) FROM singer WHERE country  =  'France'
# 100% 1/1 [00:00<00:00, 335.57it/s]
# benchmark/spider/database/concert_singer/concert_singer.sqlite
# SELECT  avg(age) ,  min(age) ,  max(age) FROM singer WHERE country  =  'France'
# ...
